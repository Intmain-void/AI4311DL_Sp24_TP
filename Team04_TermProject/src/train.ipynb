# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8 model
model = YOLO('yolov8n')  # or 'yolov8s.pt', 'yolov8m.pt', etc.
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 7.14MB/s]

# %%
import os
os.path.abspath('../dset/data.yaml')
# Out:
# 'c:\\Users\\SihyunKim\\Documents\\VSCode\\AI4311DL_Sp24_TP\\Team04_TermProject\\dset\\data.yaml'

# %%
# Train the model
import os
data_path = os.path.abspath('../dset/data.yaml')
epoch = 1
optimizer = 'RAdam'
dropout = 0.5
# model.train(data=data_path, epochs=epoch, imgsz=640, optimizer=optimizer, 
#             cos_lr=True, plots=True, dropout = dropout, batch = 12)
model.train(data=data_path, epochs=epoch, imgsz=640, optimizer=optimizer, 
            cos_lr=True, plots=True, dropout = dropout)
# Out:
# New https://pypi.org/project/ultralytics/8.2.24 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.11  Python-3.8.19 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...
